// %% [markdown]
// # Lista exercicios 06

// %% [markdown]
// ## Siga as instruções de cada exercício e utilize a estrutura de desvio de fluxo if else e a classe Scanner para interagir com o usuário e realizar os procedimentos necessários.

// %% [markdown]
// 1 - Crie uma classe em Java solicitando ao usuário para insirir o valor total de uma compra e o tipo de cliente (regular ou especial). Se for cliente especial, conceda um desconto de 10% no valor total. Caso contrário, conceda um desconto de 5%. Em seguida, exiba o valor final após o desconto.

// %%
import java.util.Scanner;
public class Atv6_1 {

    public static void main(String[ ] args ) {

        Scanner input = new Scanner(System.in);
        int desc;

        System.out.println("informe o valor da compra: ");
        int valor = input.nextInt();

        input.nextLine();

        System.out.println("informe o tipo de cliente: ");
        String cli = input.nextLine();

        if (cli.equals("regular")){
            desc = valor *5/100;  
            valor = valor - desc;  
        }
        if (cli.equals("especial")){
            desc = valor *10/100; 
            valor = valor - desc;  
        }
        else {
            System.out.println("tipo de cliente nao indentificado");
        } 
        System.out.println("Valor final pos-desconto:" + valor);
        input.close();
        } 
}

// %% [markdown]
// 2 - Crie uma classe em Java que peça ao usuário para inserir um ano e verifique se é um ano bissexto ou não. Um ano bissexto é aquele que é divisível por 4, exceto os anos que são divisíveis por 100, a menos que sejam divisíveis por 400.

// %%
import java.util.Scanner;
public class Atv6_2 {

    public static void main(String[ ] args ) {

        Scanner input = new Scanner(System.in);

        System.out.println("informe o ano a ser analisado: ");
        int ano = input.nextInt();

        if(ano % 4 == 0 || ano % 4 == 0 && ano % 100 == 0 && ano % 400 == 0) {
                System.out.println("esse è um ano bissexto");
            
            }
        if(ano % 4 != 0 || ano % 4 == 0 && ano % 100 == 0 && ano % 400 != 0)  {
                System.out.println("esse nao è um ano bissexto");
                
            }
        input.close();
        }
}

// %% [markdown]
// 3 - Crie uma classe em Java que solicite ao usuário para inserir três números e ordene-os em ordem crescente utilizando estruturas de if else.

// %%
import java.util.Scanner;
public class Atv6_3 {

    public static void main(String[ ] args ) {

        Scanner input = new Scanner(System.in);

        System.out.println("informe o primeiro numero: ");
        int n1 = input.nextInt();
        
        System.out.println("informe o segundo numero: ");
        int n2 = input.nextInt();
        
        System.out.println("informe o terceiro numero: ");
        int n3 = input.nextInt();

        if(n1 < n2 && n2 < n3){
            System.out.println("Ordem crescente: " + n1 + n2 + n3
            );
        }

        if(n1 < n2 && n3 < n2 && n1 < n3){
            System.out.println("Ordem crescente: " + n1 + n3 + n2
            );
        }

        if(n2 < n1 && n1 < n3){
            System.out.println("Ordem crescente: " + n2 + n1 + n3
            );
        }

        if(n2 < n1 && n3 < n1 && n2 < n3){
            System.out.println("Ordem crescente: " + n2 + n3 + n1
            );
        }

        if(n3 < n1 && n1 < n2){
            System.out.println("Ordem crescente: " + n3 + n1 + n2
            );
        }
        if(n3 < n1 && n2 < n1 && n3 < n2){
            System.out.println("Ordem crescente: " + n3 + n2 + n1
            );
        }

        input.close();
        }
}

// %% [markdown]
// 4 - Crie uma classe em Java que solicite uma letra do usuário e use if else para determinar se é uma vogal ou consoante.

// %%
import java.util.Scanner;
public class Atv6_4 {

    public static void main(String[ ] args ) {

        Scanner input = new Scanner(System.in);
        
        System.out.println("informe uma letra para ser verificada: ");
        String lt = input.nextLine();

        if(lt.equals("a") || lt.equals("e") || lt.equals("i") || lt.equals("o") || lt.equals("u")){
            System.out.println("a letra " + lt.toUpperCase() + " é uma vogal");
        }
        else if(lt.equals("b") || lt.equals("c") || lt.equals("d") || lt.equals("f") || lt.equals("g") || lt.equals("h") || lt.equals("j") || lt.equals("k") || lt.equals("l") || lt.equals("m") || lt.equals("n") || lt.equals("p") || lt.equals("q") || lt.equals("r") || lt.equals("s") || lt.equals("t") || lt.equals("v")|| lt.equals("w") || lt.equals("x") || lt.equals("y") || lt.equals("z")){
            System.out.println("a letra " + lt.toUpperCase() + " é uma consoante");
        }
        else {
            System.out.println("isso nem e uma letra!");
        }
        input.close();
        } 
}

// %% [markdown]
// 5 - Crie uma classe em Java que peça ao usuário para inserir três valores que representem os lados de um triângulo. Use if else para determinar se é um triângulo equilátero, isósceles ou escaleno.

// %%
import java.util.Scanner;
public class Atv6_5 {

    public static void main(String[ ] args ) {

        Scanner input = new Scanner(System.in);

        System.out.println("informe o primeiro numero: ");
        int l1 = input.nextInt();
        
        System.out.println("informe o segundo numero: ");
        int l2 = input.nextInt();
        
        System.out.println("informe o terceiro numero: ");
        int l3 = input.nextInt();

        if(l1 == l2 && l2 == l3){
            System.out.println("esse é um triangulo equilatero");
        }

        if(l1 != l2 && l2 != l3 && l3 != l1){
            System.out.println("esse é um triangulo escaleno");
        }

        if(l1 == l2 && l2 != l3 || l1 == l3 && l3 != l2 || l2 == l3 && l3 != l1){
            System.out.println("esse é um triangulo isóceles");
        }

        input.close();
        }  
}
